# %% [markdown]
# <a href="https://colab.research.google.com/github/AyobamiMichael/StarsWarsDataAnalysis/blob/main/starwarsurvey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f34f7351-e247-4601-a2e3-8a39cb8fdbf0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f34f7351-e247-4601-a2e3-8a39cb8fdbf0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
star_wars = pd.read_csv("/content/StarwarsData/StarWars.csv", encoding="ISO-8859-1")

# %%
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %%
star_wars.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %% [markdown]
# # The Yes or No response in the data should be changed to True or Flase for better analysis

# %%
yes_no = {"Yes": True, "No": False}

for col in [
    "Have you seen any of the 6 films in the Star Wars franchise?",
    "Do you consider yourself to be a fan of the Star Wars film franchise?"
    ]:
    star_wars[col] = star_wars[col].map(yes_no)

star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                                NaN
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                                NaN
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %%
star_wars[col]
# Out:
# 0         NaN
# 1        True
# 2         NaN
# 3       False
# 4        True
#         ...
# 1182     True
# 1183     True
# 1184      NaN
# 1185     True
# 1186    False
# Name: Do you consider yourself to be a fan of the Star Wars film franchise?, Length: 1187, dtype: object

# %% [markdown]
# # For questions the requires the respondent to fill check boxes, it is best to analyze such using True or False response

# %%
import numpy as np

movie_mapping = {
    "Star Wars: Episode I  The Phantom Menace": True,
    np.nan: False,
    "Star Wars: Episode II  Attack of the Clones": True,
    "Star Wars: Episode III  Revenge of the Sith": True,
    "Star Wars: Episode IV  A New Hope": True,
    "Star Wars: Episode V The Empire Strikes Back": True,
    "Star Wars: Episode VI Return of the Jedi": True
}

for col in star_wars.columns[3:9]:
    star_wars[col] = star_wars[col].map(movie_mapping)

# %% [markdown]
# # The seen Star wars columns are renamed

# %%
star_wars = star_wars.rename(columns={
        "Which of the following Star Wars films have you seen? Please select all that apply.": "seen_1",
        "Unnamed: 4": "seen_2",
        "Unnamed: 5": "seen_3",
        "Unnamed: 6": "seen_4",
        "Unnamed: 7": "seen_5",
        "Unnamed: 8": "seen_6"
        })

star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                                NaN
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                                NaN
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  \
# 0    True    True    True    True    True    True
# 1    True    True    True    True    True    True
# 2   False   False   False   False   False   False
# ...

# %% [markdown]
# # Star wars films ranking columns are renamed

# %%
star_wars = star_wars.rename(columns={
        "Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.": "ranking_1",
        "Unnamed: 10": "ranking_2",
        "Unnamed: 11": "ranking_3",
        "Unnamed: 12": "ranking_4",
        "Unnamed: 13": "ranking_5",
        "Unnamed: 14": "ranking_6"
        })

star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                                NaN
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                                NaN
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  \
# 0    True    True    True    True    True    True
# 1    True    True    True    True    True    True
# 2   False   False   False   False   False   False
# ...

# %%
star_wars = star_wars.iloc[1:].reset_index(drop=True)
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0  3.292880e+09                                               True
# 1  3.292880e+09                                              False
# 2  3.292765e+09                                               True
# 3  3.292763e+09                                               True
# 4  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                               True
# 1                                                NaN
# 2                                              False
# 3                                               True
# 4                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6 ranking_1  ...  \
# 0    True    True    True    True    True    True         3  ...
# 1   False   False   False   False   False   False       NaN  ...
# ...

# %%
star_wars[star_wars.columns[9:15]] = star_wars[star_wars.columns[9:15]].astype(float)

# %%
#star_wars.iloc[:, 9:15] = star_wars.iloc[:, 9:15].fillna(0)
star_wars[star_wars.columns[9:15]].mean()
# Out:
# ranking_1    3.732934
# ranking_2    4.087321
# ranking_3    4.341317
# ranking_4    3.272727
# ranking_5    2.513158
# ranking_6    3.047847
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.bar(range(6), star_wars[star_wars.columns[9:15]].mean())
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Rankings
# Movies rating

# %%
star_wars[star_wars.columns[3:9]]
# Out:
#       seen_1  seen_2  seen_3  seen_4  seen_5  seen_6
# 0       True    True    True    True    True    True
# 1      False   False   False   False   False   False
# 2       True    True    True   False   False   False
# 3       True    True    True    True    True    True
# 4       True    True    True    True    True    True
# ...      ...     ...     ...     ...     ...     ...
# 1181    True    True    True    True    True    True
# 1182    True    True    True    True    True    True
# 1183   False   False   False   False   False   False
# 1184    True    True    True    True    True    True
# 1185    True    True   False   False    True    True
#
# [1186 rows x 6 columns]

# %%
star_wars[star_wars.columns[3:9]].sum()
# Out:
# seen_1    673
# seen_2    571
# seen_3    550
# seen_4    607
# seen_5    758
# seen_6    738
# dtype: int64

# %%
plt.bar(range(6), star_wars[star_wars.columns[3:9]].sum())
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # **View counts**
# The number of people who saw the old movies are more than the people who saw the new movies, this correlate to the ranking bar chart

# %%
males = star_wars[star_wars["Gender"] == "Male"]
females = star_wars[star_wars["Gender"] == "Female"]

# %%
 #males[males.columns[9:15]]
 star_wars["Gender"]
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3         Male
# 4         Male
#          ...
# 1181    Female
# 1182    Female
# 1183    Female
# 1184    Female
# 1185    Female
# Name: Gender, Length: 1186, dtype: object

# %%
plt.bar(range(6), males[males.columns[9:15]].mean())
plt.show()

plt.bar(range(6), females[females.columns[9:15]].mean())
plt.show()

# %%
plt.bar(range(6), males[males.columns[3:9]].sum())
plt.show()

plt.bar(range(6), females[females.columns[3:9]].sum())
plt.show()

# %%
 star_wars.to_csv('/content/StarwarsData/processedStarWarsData.csv', index=False)
